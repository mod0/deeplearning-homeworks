# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import homework2qcnn_mnist as mnist

# %%
mnist.main(None)
# Out:
# Extracting MNIST-data/train-images-idx3-ubyte.gz
# Extracting MNIST-data/train-labels-idx1-ubyte.gz
# Extracting MNIST-data/t10k-images-idx3-ubyte.gz
# Extracting MNIST-data/t10k-labels-idx1-ubyte.gz
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_model_dir': '/tmp/mnist_conv_net', '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/mnist_conv_net/model.ckpt-20000
# INFO:tensorflow:Saving checkpoints for 20001 into /tmp/mnist_conv_net/model.ckpt.
# INFO:tensorflow:loss = 0.114481, step = 20001
# INFO:tensorflow:global_step/sec: 252.806
# INFO:tensorflow:loss = 0.423497, step = 20101 (0.397 sec)
# INFO:tensorflow:global_step/sec: 268.033
# ...

# %%
import homework2qcnn_cifar100 as cifar100

# %%
trainfile = 'cifar100-data/train'
testfile  = 'cifar100-data/test'
metafile  = 'cifar100-data/meta'

# %%
cifar100.main(trainfile = trainfile,
              testfile  = testfile,
              metafile  = metafile)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_model_dir': '/tmp/cifar100_conv_net', '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/cifar100_conv_net/model.ckpt.
# INFO:tensorflow:loss = 37.6225, step = 1
# INFO:tensorflow:global_step/sec: 76.5913
# INFO:tensorflow:loss = 4.62394, step = 101 (1.307 sec)
# INFO:tensorflow:global_step/sec: 78.0408
# INFO:tensorflow:loss = 4.59446, step = 201 (1.281 sec)
# INFO:tensorflow:global_step/sec: 77.9627
# INFO:tensorflow:loss = 4.60821, step = 301 (1.283 sec)
# INFO:tensorflow:global_step/sec: 77.7362
# INFO:tensorflow:loss = 4.59989, step = 401 (1.286 sec)
# INFO:tensorflow:global_step/sec: 78.2664
# ...
